# %%
from charting_script import drawLine2P, PlotTimeSeries, Chart3PTL

# %%
Chart3PTL("""FMG.AX
RMS.AX
SFC.AX
PRU.AX
AQG.AX
STO.AX
BFG.AX
KOV.AX
RRL.AX
HAW.AX
MRC.AX
KRM.AX
GEAR.AX
AGD.AX
MML.AX""")
# Out:
# FMG.AX
# Current Price for FMG.AX is 17.86
# Sell Price for FMG.AX is 10.83
# Buy Price for FMG.AX is 15.78
# RMS.AX
# Current Price for RMS.AX is 1.93
# Sell Price for RMS.AX is 1.12
# Buy Price for RMS.AX is 2.76
# SFC.AX
# Current Price for SFC.AX is 13.04
# Sell Price for SFC.AX is 4.62
# Buy Price for SFC.AX is 13.53
# PRU.AX
# Current Price for PRU.AX is 1.41
# Sell Price for PRU.AX is 0.32
# AQG.AX
# Current Price for AQG.AX is 8.71
# Sell Price for AQG.AX is 4.9
# Buy Price for AQG.AX is 12.79
# STO.AX
# Current Price for STO.AX is 5.83
# Sell Price for STO.AX is 3.48
# Buy Price for STO.AX is 2.86
# BFG.AX
# Current Price for BFG.AX is 1.26
# Sell Price for BFG.AX is 0.84
# Buy Price for BFG.AX is 1.95
# KOV.AX
# Current Price for KOV.AX is 4.95
# Sell Price for KOV.AX is 3.74
# Buy Price for KOV.AX is 5.93
# RRL.AX
# Current Price for RRL.AX is 5.44
# Sell Price for RRL.AX is 5.45
# Buy Price for RRL.AX is 6.17
# HAW.AX
# Current Price for HAW.AX is 0.14
# ...
