# %%
from charting_script import drawLine2P, PlotTimeSeries, Chart3PTL

# %%
Chart3PTL("""
ATD-B.TO
ASR.TO
FMG.AX
RMS.AX
SFC.AX
PRU.AX
AQG.AX
STO.AX
BFG.AX
KOV.AX
RRL.AX
HAW.AX
MRC.AX
KRM.AX
GEAR.AX
AGD.AX
MML.AX""")
# Out:
# ATD-B.TO
# Current Price for ATD-B.TO is 44.63
# Sell Price for ATD-B.TO is 45.05
# Buy Price for ATD-B.TO is 46.28
# ASR.TO
# Current Price for ASR.TO is 9.47
# Sell Price for ASR.TO is 4.99
# Buy Price for ASR.TO is 11.15
# FMG.AX
# Current Price for FMG.AX is 16.66
# Sell Price for FMG.AX is 10.04
# Buy Price for FMG.AX is 10.32
# RMS.AX
# Current Price for RMS.AX is 2.22
# Sell Price for RMS.AX is 1.12
# Buy Price for RMS.AX is 1.37
# SFC.AX
# Current Price for SFC.AX is 15.65
# Sell Price for SFC.AX is 7.27
# Buy Price for SFC.AX is 16.18
# PRU.AX
# Current Price for PRU.AX is 1.39
# Sell Price for PRU.AX is 0.32
# AQG.AX
# Current Price for AQG.AX is 9.4
# Sell Price for AQG.AX is 2.37
# Buy Price for AQG.AX is 1.55
# STO.AX
# Current Price for STO.AX is 5.26
# Sell Price for STO.AX is 5.45
# Buy Price for STO.AX is 1.2
# BFG.AX
# Current Price for BFG.AX is 1.27
# Sell Price for BFG.AX is 1.4
# Buy Price for BFG.AX is 2.41
# KOV.AX
# Current Price for KOV.AX is 4.63
# ...
