# %%
from charting_script import drawLine2P, PlotTimeSeries, Chart3PTL

# %%
Chart3PTL("""
AAPL
ENB.TO
CP.TO
RMS.AX
KOV.AX
RRL.AX
HAW.AX
MRC.AX""", verbose_mode=False)
# Out:
# AAPL
# Current Price for AAPL is 127.45
# Sell Price for AAPL is 120.3
# Buy Price for AAPL is 195.46
# ENB.TO
# Current Price for ENB.TO is 47.2
# Sell Price for ENB.TO is 42.25
# Buy Price for ENB.TO is 47.22
# CP.TO
# Current Price for CP.TO is 97.01
# Sell Price for CP.TO is 85.87
# Buy Price for CP.TO is 90.15
# RMS.AX
# Current Price for RMS.AX is 1.74
# Sell Price for RMS.AX is 1.32
# Buy Price for RMS.AX is 1.41
# KOV.AX
# Current Price for KOV.AX is 4.7
# Sell Price for KOV.AX is 3.66
# Buy Price for KOV.AX is 5.34
# RRL.AX
# Current Price for RRL.AX is 2.58
# Sell Price for RRL.AX is 3.8
# Buy Price for RRL.AX is 5.2
# HAW.AX
# Current Price for HAW.AX is 0.05
# Sell Price for HAW.AX is 0.04
# Buy Price for HAW.AX is 0.13
# MRC.AX
# Current Price for MRC.AX is 0.22
# Sell Price for MRC.AX is 0.11

# %%
Chart3PTL("""
AAPL
ENB.TO
CP.TO
RMS.AX
KOV.AX
RRL.AX
HAW.AX
MRC.AX""", verbose_mode=True)
# Out:
# AAPL
# Current Price for AAPL is 127.45
# AAPL Sell Breach at 2018-11-01, this is Breach #1
# AAPL Buy Breach at 2019-06-01, this is Breach #2
# AAPL Sell Breach at 2019-06-01, this is Breach #3
# AAPL Buy Breach at 2019-09-01, this is Breach #4
# AAPL Sell Breach at 2019-09-01, this is Breach #5
# AAPL Buy Breach at 2020-06-01, this is Breach #6
# AAPL Sell Breach at 2020-06-01, this is Breach #7
# AAPL Buy Breach at 2020-08-01, this is Breach #8
# Sell Price for AAPL is 120.3
# Buy Price for AAPL is 195.46
# ENB.TO
# Current Price for ENB.TO is 47.2
# ENB.TO Sell Breach at 2017-11-01, this is Breach #1
# ENB.TO Buy Breach at 2017-12-01, this is Breach #2
# ENB.TO Sell Breach at 2018-02-01, this is Breach #3
# ENB.TO Buy Breach at 2019-01-01, this is Breach #4
# ENB.TO Sell Breach at 2019-05-01, this is Breach #5
# ENB.TO Buy Breach at 2020-01-01, this is Breach #6
# ENB.TO Sell Breach at 2020-09-01, this is Breach #7
# ENB.TO Buy Breach at 2021-04-01, this is Breach #8
# Sell Price for ENB.TO is 42.25
# Buy Price for ENB.TO is 47.22
# CP.TO
# Current Price for CP.TO is 97.01
# CP.TO Sell Breach at 2017-02-01, this is Breach #1
# CP.TO Buy Breach at 2017-10-01, this is Breach #2
# CP.TO Sell Breach at 2018-01-01, this is Breach #3
# CP.TO Buy Breach at 2018-02-01, this is Breach #4
# CP.TO Sell Breach at 2018-12-01, this is Breach #5
# CP.TO Buy Breach at 2019-04-01, this is Breach #6
# CP.TO Sell Breach at 2019-09-01, this is Breach #7
# CP.TO Buy Breach at 2020-09-01, this is Breach #8
# Sell Price for CP.TO is 85.87
# Buy Price for CP.TO is 90.15
# RMS.AX
# Current Price for RMS.AX is 1.74
# RMS.AX Sell Breach at 2017-09-01, this is Breach #1
# RMS.AX Buy Breach at 2017-11-01, this is Breach #2
# RMS.AX Sell Breach at 2018-11-01, this is Breach #3
# RMS.AX Buy Breach at 2019-05-01, this is Breach #4
# RMS.AX Sell Breach at 2019-06-01, this is Breach #5
# RMS.AX Buy Breach at 2019-08-01, this is Breach #6
# RMS.AX Sell Breach at 2019-11-01, this is Breach #7
# RMS.AX Buy Breach at 2020-04-01, this is Breach #8
# Sell Price for RMS.AX is 1.32
# Buy Price for RMS.AX is 1.41
# KOV.AX
# Current Price for KOV.AX is 4.7
# KOV.AX Sell Breach at 2018-06-01, this is Breach #1
# KOV.AX Buy Breach at 2018-09-01, this is Breach #2
# KOV.AX Sell Breach at 2019-04-01, this is Breach #3
# KOV.AX Buy Breach at 2020-01-01, this is Breach #4
# Sell Price for KOV.AX is 3.66
# Buy Price for KOV.AX is 5.34
# RRL.AX
# Current Price for RRL.AX is 2.58
# RRL.AX Sell Breach at 2017-09-01, this is Breach #1
# RRL.AX Buy Breach at 2017-12-01, this is Breach #2
# RRL.AX Sell Breach at 2018-07-01, this is Breach #3
# RRL.AX Buy Breach at 2019-02-01, this is Breach #4
# RRL.AX Sell Breach at 2019-11-01, this is Breach #5
# RRL.AX Buy Breach at 2020-04-01, this is Breach #6
# RRL.AX Sell Breach at 2020-04-01, this is Breach #7
# RRL.AX Buy Breach at 2020-07-01, this is Breach #8
# RRL.AX Sell Breach at 2021-01-01, this is Breach #9
# Sell Price for RRL.AX is 3.8
# Buy Price for RRL.AX is 5.2
# HAW.AX
# Current Price for HAW.AX is 0.05
# Sell Price for HAW.AX is 0.04
# Buy Price for HAW.AX is 0.13
# MRC.AX
# Current Price for MRC.AX is 0.22
# Sell Price for MRC.AX is 0.11
