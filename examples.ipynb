# %%
from charting_script import drawLine2P, PlotTimeSeries, Chart3PTL

# %%
Chart3PTL("""ASR.TO
FMG.AX
RMS.AX
SFC.AX
PRU.AX
AQG.AX
STO.AX
BFG.AX
KOV.AX
RRL.AX
HAW.AX
MRC.AX
KRM.AX
GEAR.AX
AGD.AX
MML.AX""")
# Out:
# ASR.TO
# Current Price for ASR.TO is 9.45
# Sell Price for ASR.TO is 4.71
# Buy Price for ASR.TO is 11.59
# FMG.AX
# Current Price for FMG.AX is 17.71
# Sell Price for FMG.AX is 10.99
# Buy Price for FMG.AX is 10.24
# RMS.AX
# Current Price for RMS.AX is 2.36
# Sell Price for RMS.AX is 1.19
# Buy Price for RMS.AX is 2.47
# SFC.AX
# Current Price for SFC.AX is 16.0
# Sell Price for SFC.AX is 4.62
# Buy Price for SFC.AX is 16.22
# PRU.AX
# Current Price for PRU.AX is 1.46
# Sell Price for PRU.AX is 0.32
# AQG.AX
# Current Price for AQG.AX is 9.4
# Sell Price for AQG.AX is 8.0
# Buy Price for AQG.AX is 13.31
# STO.AX
# Current Price for STO.AX is 5.24
# Sell Price for STO.AX is 3.49
# Buy Price for STO.AX is 5.24
# BFG.AX
# Current Price for BFG.AX is 1.1
# Sell Price for BFG.AX is 1.41
# Buy Price for BFG.AX is 2.36
# KOV.AX
# Current Price for KOV.AX is 4.5
# Sell Price for KOV.AX is 4.51
# Buy Price for KOV.AX is 4.75
# RRL.AX
# Current Price for RRL.AX is 5.34
# ...
